# %% [markdown]
# ## Code for Sharing EMA Data

# %%
from pyprojroot import here
import sys
sys.path.insert(0, str(here()))

# --- Paths / imports -------------------------------------------------
PROJECT_ROOT = here()

# --- Paths / imports -------------------------------------------------
import pickle
from server_config import redcap_path, preprocessed_path, sp1_path
import pandas as pd
import numpy as np
from scipy.stats import norm, rankdata
# Out:
# Couldn't load .env file, continuing with defaults

# %%
with open(preprocessed_path + '/ema_content.pkl', 'rb') as file:
    df_ema_content = pickle.load(file)  

with open(preprocessed_path + '/monitoring_data.pkl', 'rb') as file:
    df_monitoring = pickle.load(file)
    
df_sp1_completer_plus = pd.read_spss(sp1_path + "/Baseline" + "/sample_completer_plus_260704.sav")

# %%
# rename column
df_ema_content = df_ema_content.rename(
    columns={
        'n_beeps_beeps_completed_per_burst': 'n_beeps_completed_per_burst'
    }
)

# %%
# manual correction
replacements = {
    ('mASG', 1): 81,
    ('9UHX', 1): 70,
    ('LQFF', 1): 96,
    ('uxmL', 1): 114,
    ('mASG', 2): 80
}

for (pid, burst), value in replacements.items():
    
    mask = (
        (df_ema_content['id'] == pid) &
        (df_ema_content['measurement_burst'] == burst)
    )
    
    df_ema_content.loc[
        mask,
        'n_beeps_completed_per_burst'
    ] = value

# %%
# sanity check
#df_ema_content.loc[
#    (df_ema_content['measurement_burst'] == 2) &
#    (df_ema_content['id'] == 'mASG'),
#    ['timestamp_beep_completion']
#].nunique()

# %%
col_list_redcap =['for_id', 'age','gender', 'marital_status',
 'partnership',
 'graduation',
 'profession',
 'years_of_education',
 'employability',
 'prior_treatment',
 'medication',
 'psychotropic','ses','scid_cv_prim','hama_red_t20', 'hama_red_post',
'ybocs_red_t20', 'ybocs_red_post', 'caps_red_t20', 'caps_red_post', 'response_specific_t20', 'response_specific_post', 'bdi_sum_1', 
'bdi_sum_3', 'bdi_sum_4','bsi_gsi_4', 'bsi_gsi_3', 'bsi_gsi_1', 'asi_total_4', 'asi_total_3', 'asi_total_1', 
'hferst_date_1','hferst1_1','hferst2_1','hferst3_1','hferst4_1','hferst5_1','hferst6_1','hferst7_1','hferst8_1',
 'hferst9_1',
 'hferst10_1',
 'hferst11_1',
 'hferst12_1',
 'hferst13_1',
 'hferst14_1',
 'hferst15_1',
 'hferst16_1',
 'hferst17_1',
 'hferst18_1',
 'hferst19_1',
 'hferst20_1',
 'hferst21_1',
 'hferst22_1',
 'hferst23_1',
 'hferst24_1',
 'hferst25_1',
 'hferst26_1',
 'hferst27_1',
 'hferst28_1',
 'hferst_rumination_1',
 'hferst_reappraisal_1',
 'hferst_acceptance_1',
 'hferst_problem_solving_1',
 'hferst_expression_suppr_1',
 'hferst_experience_suppr_1',
 'hferst_avoidance_1',
 'hferst_social_supp_1',
 'hferst_complete_1',
 'hferst_timestamp_2',
 'hferst_date_2',
 'hferst1_2',
 'hferst2_2',
 'hferst3_2',
 'hferst4_2',
 'hferst5_2',
 'hferst6_2',
 'hferst7_2',
 'hferst8_2',
 'hferst9_2',
 'hferst10_2',
 'hferst11_2',
 'hferst12_2',
 'hferst13_2',
 'hferst14_2',
 'hferst15_2',
 'hferst16_2',
 'hferst17_2',
 'hferst18_2',
 'hferst19_2',
 'hferst20_2',
 'hferst21_2',
 'hferst22_2',
 'hferst23_2',
 'hferst24_2',
 'hferst25_2',
 'hferst26_2',
 'hferst27_2',
 'hferst28_2',
 'hferst_rumination_2',
 'hferst_reappraisal_2',
 'hferst_acceptance_2',
 'hferst_problem_solving_2',
 'hferst_expression_suppr_2',
 'hferst_experience_suppr_2',
 'hferst_avoidance_2',
 'hferst_social_supp_2',
 'hferst_complete_2',
 'hferst_timestamp_3',
 'hferst_date_3',
 'hferst1_3',
 'hferst2_3',
 'hferst3_3',
 'hferst4_3',
 'hferst5_3',
 'hferst6_3',
 'hferst7_3',
 'hferst8_3',
 'hferst9_3',
 'hferst10_3',
 'hferst11_3',
 'hferst12_3',
 'hferst13_3',
 'hferst14_3',
 'hferst15_3',
 'hferst16_3',
 'hferst17_3',
 'hferst18_3',
 'hferst19_3',
 'hferst20_3',
 'hferst21_3',
 'hferst22_3',
 'hferst23_3',
 'hferst24_3',
 'hferst25_3',
 'hferst26_3',
 'hferst27_3',
 'hferst28_3',
 'hferst_rumination_3',
 'hferst_reappraisal_3',
 'hferst_acceptance_3',
 'hferst_problem_solving_3',
 'hferst_expression_suppr_3',
 'hferst_experience_suppr_3',
 'hferst_avoidance_3',
 'hferst_social_supp_3',
 'hferst_complete_3',
 'hferst_timestamp_4',
 'hferst_date_4',
 'hferst1_4',
 'hferst2_4',
 'hferst3_4',
 'hferst4_4',
 'hferst5_4',
 'hferst6_4',
 'hferst7_4',
 'hferst8_4',
 'hferst9_4',
 'hferst10_4',
 'hferst11_4',
 'hferst12_4',
 'hferst13_4',
 'hferst14_4',
 'hferst15_4',
 'hferst16_4',
 'hferst17_4',
 'hferst18_4',
 'hferst19_4',
 'hferst20_4',
 'hferst21_4',
 'hferst22_4',
 'hferst23_4',
 'hferst24_4',
 'hferst25_4',
 'hferst26_4',
 'hferst27_4',
 'hferst28_4',
 'hferst_rumination_4',
 'hferst_reappraisal_4',
 'hferst_acceptance_4',
 'hferst_problem_solving_4',
 'hferst_expression_suppr_4',
 'hferst_experience_suppr_4',
 'hferst_avoidance_4',
 'hferst_social_supp_4',
 'hferst_complete_4','pass_sum_1','pass_sum_3','pass_sum_4', 'cerq1_1',
 'cerq2_1',
 'cerq3_1',
 'cerq4_1',
 'cerq5_1',
 'cerq6_1',
 'cerq7_1',
 'cerq8_1',
 'cerq9_1',
 'cerq10_1',
 'cerq11_1',
 'cerq12_1',
 'cerq13_1',
 'cerq14_1',
 'cerq15_1',
 'cerq16_1',
 'cerq17_1',
 'cerq18_1',
 'cerq_self_blame_1',
 'cerq_acceprance_1',
 'cerq_rumination_1',
 'cerq_pos_refocusing_1',
 'cerq_ref_planing_1',
 'cerq_pos_reappraisal_1',
 'cerq_perspective_1',
 'cerq_catastrophizing_1',
 'cerq_other_blame_1',
 'cerq_complete_1',
 'cerq_timestamp_2',
 'cerq_date_2',
 'cerq1_2',
 'cerq2_2',
 'cerq3_2',
 'cerq4_2',
 'cerq5_2',
 'cerq6_2',
 'cerq7_2',
 'cerq8_2',
 'cerq9_2',
 'cerq10_2',
 'cerq11_2',
 'cerq12_2',
 'cerq13_2',
 'cerq14_2',
 'cerq15_2',
 'cerq16_2',
 'cerq17_2',
 'cerq18_2',
 'cerq_self_blame_2',
 'cerq_acceprance_2',
 'cerq_rumination_2',
 'cerq_pos_refocusing_2',
 'cerq_ref_planing_2',
 'cerq_pos_reappraisal_2',
 'cerq_perspective_2',
 'cerq_catastrophizing_2',
 'cerq_other_blame_2',
 'cerq_complete_2',
 'cerq_timestamp_3',
 'cerq_date_3',
 'cerq1_3',
 'cerq2_3',
 'cerq3_3',
 'cerq4_3',
 'cerq5_3',
 'cerq6_3',
 'cerq7_3',
 'cerq8_3',
 'cerq9_3',
 'cerq10_3',
 'cerq11_3',
 'cerq12_3',
 'cerq13_3',
 'cerq14_3',
 'cerq15_3',
 'cerq16_3',
 'cerq17_3',
 'cerq18_3',
 'cerq_self_blame_3',
 'cerq_acceprance_3',
 'cerq_rumination_3',
 'cerq_pos_refocusing_3',
 'cerq_ref_planing_3',
 'cerq_pos_reappraisal_3',
 'cerq_perspective_3',
 'cerq_catastrophizing_3',
 'cerq_other_blame_3',
 'cerq_complete_3',
 'cerq_timestamp_4',
 'cerq_date_4',
 'cerq1_4',
 'cerq2_4',
 'cerq3_4',
 'cerq4_4',
 'cerq5_4',
 'cerq6_4',
 'cerq7_4',
 'cerq8_4',
 'cerq9_4',
 'cerq10_4',
 'cerq11_4',
 'cerq12_4',
 'cerq13_4',
 'cerq14_4',
 'cerq15_4',
 'cerq16_4',
 'cerq17_4',
 'cerq18_4',
 'cerq_self_blame_4',
 'cerq_acceprance_4',
 'cerq_rumination_4',
 'cerq_pos_refocusing_4',
 'cerq_ref_planing_4',
 'cerq_pos_reappraisal_4',
 'cerq_perspective_4',
 'cerq_catastrophizing_4',
 'cerq_other_blame_4', 
 'berq_date_1',
 'berq1_1',
 'berq2_1',
 'berq3_1',
 'berq4_1',
 'berq5_1',
 'berq6_1',
 'berq7_1',
 'berq8_1',
 'berq9_1',
 'berq10_1',
 'berq11_1',
 'berq12_1',
 'berq13_1',
 'berq14_1',
 'berq15_1',
 'berq16_1',
 'berq17_1',
 'berq18_1',
 'berq19_1',
 'berq20_1',
 'berq_distraction_1',
 'berq_withdrawal_1',
 'berq_approaching_1',
 'berq_support_1',
 'berq_ignoring_1',
 'berq_complete_1',
 'berq_timestamp_2',
 'berq_date_2',
 'berq1_2',
 'berq2_2',
 'berq3_2',
 'berq4_2',
 'berq5_2',
 'berq6_2',
 'berq7_2',
 'berq8_2',
 'berq9_2',
 'berq10_2',
 'berq11_2',
 'berq12_2',
 'berq13_2',
 'berq14_2',
 'berq15_2',
 'berq16_2',
 'berq17_2',
 'berq18_2',
 'berq19_2',
 'berq20_2',
 'berq_distraction_2',
 'berq_withdrawal_2',
 'berq_approaching_2',
 'berq_support_2',
 'berq_ignoring_2',
 'berq_complete_2',
 'berq_timestamp_3',
 'berq_date_3',
 'berq1_3',
 'berq2_3',
 'berq3_3',
 'berq4_3',
 'berq5_3',
 'berq6_3',
 'berq7_3',
 'berq8_3',
 'berq9_3',
 'berq10_3',
 'berq11_3',
 'berq12_3',
 'berq13_3',
 'berq14_3',
 'berq15_3',
 'berq16_3',
 'berq17_3',
 'berq18_3',
 'berq19_3',
 'berq20_3',
 'berq_distraction_3',
 'berq_withdrawal_3',
 'berq_approaching_3',
 'berq_support_3',
 'berq_ignoring_3',
 'berq_complete_3',
 'berq_timestamp_4',
 'berq_date_4',
 'berq1_4',
 'berq2_4',
 'berq3_4',
 'berq4_4',
 'berq5_4',
 'berq6_4',
 'berq7_4',
 'berq8_4',
 'berq9_4',
 'berq10_4',
 'berq11_4',
 'berq12_4',
 'berq13_4',
 'berq14_4',
 'berq15_4',
 'berq16_4',
 'berq17_4',
 'berq18_4',
 'berq19_4',
 'berq20_4',
 'berq_distraction_4',
 'berq_withdrawal_4',
 'berq_approaching_4',
 'berq_support_4',
 'berq_ignoring_4', 
 'tex1_1',
 'tex2_1',
 'tex3_1',
 'tex4_1',
 'tex5_1',
 'tex6_1',
 'tex7_1',
 'tex8_1',
 'tex9_1',
 'tex10_1',
 'tex11_1',
 'tex12_1',
 'tex13_1',
 'tex14_1',
 'tex15_1',
 'tex_symptomreduction_1',
 'tex_positive_impact_1',
 'tex_adverse_effects_1',
 'tex_negative_impact_1',
 'tex_process_exp_1',
 'tex_control_exp_1',
 'tex_total_1',
 'texq_complete_1',
 'texq_timestamp_2',
 'tex_date_2',
 'tex1_2',
 'tex2_2',
 'tex3_2',
 'tex4_2',
 'tex5_2',
 'tex6_2',
 'tex7_2',
 'tex8_2',
 'tex9_2',
 'tex10_2',
 'tex11_2',
 'tex12_2',
 'tex13_2',
 'tex14_2',
 'tex15_2',
 'tex_symptomreduction_2',
 'tex_positive_impact_2',
 'tex_adverse_effects_2',
 'tex_negative_impact_2',
 'tex_process_exp_2',
 'tex_control_exp_2',
 'tex_total_2',
 'texq_complete_2']

# %%
df_red_short = df_sp1_completer_plus[col_list_redcap]

# %% [markdown]
# #### Keep Columns necessary for Network Analysis

# %%
df_network = df_ema_content[['id', 'for_id', 'measurement_burst','item','response','beep_per_person_id', 'n_beeps_completed_per_burst', 'timestamp_item_completion', 'nr_beep_daily']]

# %% [markdown]
# ### Pivot dataframe

# %%
# Keep PANAS items and all items starting with er_
df_ema_items = df_network[
    df_network["item"].str.startswith(("panas_", "er_"), na=False)
].copy()

extra_cols = ["measurement_burst", "for_id",  "n_beeps_completed_per_burst", 'timestamp_item_completion', 'nr_beep_daily']

# Keep one row per id + beep_per_person_id with the extra columns
aggregated_info = (
    df_ema_items
    .groupby(["id", "beep_per_person_id"])[extra_cols]
    .first()
    .reset_index()
)

# Pivot item responses to wide format
df_items_piv = df_ema_items.pivot_table(
    index=["id", "beep_per_person_id"],
    columns="item",
    values="response",
    aggfunc="first"
)

# Flatten columns
df_items_piv.columns = [col for col in df_items_piv.columns]

# Reset index
df_items_piv = df_items_piv.reset_index()

# Merge extra columns back in
df_items_piv = df_items_piv.merge(
    aggregated_info,
    on=["id", "beep_per_person_id"],
    how="left"
)

# Optional: remove duplicates
df_items_piv = df_items_piv.drop_duplicates()

# %%
df_items_piv.sort_values("timestamp_item_completion", na_position="last").tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_items_piv.sort_values("timestamp_item_completion", na_position="last").tail(20)
#
# NameError: name 'df_items_piv' is not defined

# %%
b

# %%
na_cols = ['panas_fear1', 'panas_fear2', 'panas_guilt1','panas_guilt2', 'panas_hostility1', 'panas_hostility2','panas_sadness1', 'panas_sadness2']
pa_cols = ['panas_attentiveness', 'panas_joviality1', 'panas_joviality2','panas_selfassurance','panas_serenity1', 'panas_serenity2']

df_items_piv[pa_cols + na_cols] = df_items_piv[pa_cols + na_cols].apply(
    pd.to_numeric, errors="coerce"
)

# %%
group_cols = ['id', 'beep_per_person_id', 'measurement_burst']

scale_defs = {
    'panas_na':        na_cols,
    'panas_pa':        pa_cols 
}
for new_col, cols in scale_defs.items():
    df_items_piv[new_col] = (
        df_items_piv
        .groupby(group_cols)[cols]
        .transform('mean')
        .mean(axis=1)
    )

# %%
#df_items_piv.to_csv("data_doro_network.csv")
df_items_piv.to_csv(
    preprocessed_path + "/data_teresa.csv",
    index=False
)

# %%
df_red_short.to_csv(preprocessed_path + "/data_red_short.csv", index=False)
